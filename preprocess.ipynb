# %%
import pandas as pd

# %%
df = pd.read_excel('static/data/results.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0         NaN         NaN        NaN        NaN         NaN
# 1         NaN         NaN        NaN        NaN         NaN
# 2         NaN         NaN        NaN        NaN         NaN
# 3         NaN         NaN        NaN        NaN         NaN
# 4         NaN         NaN        NaN        NaN         NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1   Unnamed: 2             Unnamed: 3  Unnamed: 4
# 0          NaN         NaN          NaN                    NaN         NaN
# 1          NaN         NaN          NaN                    NaN         NaN
# 2          NaN         NaN          NaN                    NaN         NaN
# 3          NaN         NaN          NaN                    NaN         NaN
# 4          NaN         NaN          NaN                    NaN         NaN
# ..         ...         ...          ...                    ...         ...
# 59         NaN        28.0   S190302029   KENGAR SIDDHI SURESH        7.05
# 60         NaN        42.0   S190302043    MORE PRATIK NAGNATH        6.91
# 61         NaN        24.0   S190302025     HINGE NIKHIL SUNIL        6.89
# 62         NaN        52.0   S190302053    SABLE ADWAIT ASHISH        6.86
# 63         NaN         8.0   S190302008   BAWKAR SNEHAL MAHESH        6.41
#
# [64 rows x 5 columns]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#     Unnamed: 1   Unnamed: 2             Unnamed: 3  Unnamed: 4
# 0          NaN          NaN                    NaN         NaN
# 1          NaN          NaN                    NaN         NaN
# 2          NaN          NaN                    NaN         NaN
# 3          NaN          NaN                    NaN         NaN
# 4          NaN          NaN                    NaN         NaN
# ..         ...          ...                    ...         ...
# 59        28.0   S190302029   KENGAR SIDDHI SURESH        7.05
# 60        42.0   S190302043    MORE PRATIK NAGNATH        6.91
# 61        24.0   S190302025     HINGE NIKHIL SUNIL        6.89
# 62        52.0   S190302053    SABLE ADWAIT ASHISH        6.86
# 63         8.0   S190302008   BAWKAR SNEHAL MAHESH        6.41
#
# [64 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Unnamed: 1   Unnamed: 2                    Unnamed: 3  Unnamed: 4
# 19         7.0   S190302007         BARI DIVESH SHYAMKANT        9.25
# 20        10.0   S190302010          BHAGWAT PRATHAMESH R        9.02
# 21        45.0   S190302046         NIKAM TEJAS RAGHUNATH        8.93
# 22        37.0   S190302038           MAHAJAN ANSH PRADIP        8.84
# 23        62.0   S190302063        SWATHI SUDHAKAR PEPETI        8.84
# 24        61.0   S190302062       SUTAR SHRIKRISHNA ASHOK        8.80
# 25        51.0   S190302052                   RUDRA LAGDE        8.75
# 26        35.0   S190302036             KUHAR ADITI DILIP        8.59
# 27        57.0   S190302058     SHANBHAG PRAHLAD NARSINHA        8.59
# 28        56.0   S190302057       SHAIKH ABDULKARIM SALIM        8.52
# 29        53.0   S190302054        SANDEEP MALHARI BORKAR        8.45
# 30        19.0   S190302020           GITE SARTHAK SANDIP        8.41
# ...

# %%
df.drop(columns=['Unnamed: 1'],inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 2               Unnamed: 3  Unnamed: 4
# 19   S190302007    BARI DIVESH SHYAMKANT        9.25
# 20   S190302010     BHAGWAT PRATHAMESH R        9.02
# 21   S190302046    NIKAM TEJAS RAGHUNATH        8.93
# 22   S190302038      MAHAJAN ANSH PRADIP        8.84
# 23   S190302063   SWATHI SUDHAKAR PEPETI        8.84

# %%
df
# Out:
#      Unnamed: 2                    Unnamed: 3  Unnamed: 4
# 19   S190302007         BARI DIVESH SHYAMKANT        9.25
# 20   S190302010          BHAGWAT PRATHAMESH R        9.02
# 21   S190302046         NIKAM TEJAS RAGHUNATH        8.93
# 22   S190302038           MAHAJAN ANSH PRADIP        8.84
# 23   S190302063        SWATHI SUDHAKAR PEPETI        8.84
# 24   S190302062       SUTAR SHRIKRISHNA ASHOK        8.80
# 25   S190302052                   RUDRA LAGDE        8.75
# 26   S190302036             KUHAR ADITI DILIP        8.59
# 27   S190302058     SHANBHAG PRAHLAD NARSINHA        8.59
# 28   S190302057       SHAIKH ABDULKARIM SALIM        8.52
# 29   S190302054        SANDEEP MALHARI BORKAR        8.45
# 30   S190302020           GITE SARTHAK SANDIP        8.41
# 31   S190302024             HAKIM SANIYA MUSA        8.39
# 32   S190302039     MAHANGADE SHREYAS RAJARAM        8.39
# 33   S190302015       GANDHALE SWAPNIL SAMPAT        8.34
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df = df.rename(columns={'Unnamed: 2':'Seat No.','Unnamed: 3':'Names','Unnamed: 4':'SGPA'})

# %%
df.head()
# Out:
#        Seat No.                    Names  SGPA
# 19   S190302007    BARI DIVESH SHYAMKANT  9.25
# 20   S190302010     BHAGWAT PRATHAMESH R  9.02
# 21   S190302046    NIKAM TEJAS RAGHUNATH  8.93
# 22   S190302038      MAHAJAN ANSH PRADIP  8.84
# 23   S190302063   SWATHI SUDHAKAR PEPETI  8.84

# %%
df.to_csv("new_df.csv")

# %%
new_df = pd.read_csv('static/data/new_df.csv')

# %%
new_df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
new_df
# Out:
#        Seat No.                         Names  SGPA
# 0    S190302007         BARI DIVESH SHYAMKANT  9.25
# 1    S190302010          BHAGWAT PRATHAMESH R  9.02
# 2    S190302046         NIKAM TEJAS RAGHUNATH  8.93
# 3    S190302038           MAHAJAN ANSH PRADIP  8.84
# 4    S190302063        SWATHI SUDHAKAR PEPETI  8.84
# 5    S190302062       SUTAR SHRIKRISHNA ASHOK  8.80
# 6    S190302052                   RUDRA LAGDE  8.75
# 7    S190302036             KUHAR ADITI DILIP  8.59
# 8    S190302058     SHANBHAG PRAHLAD NARSINHA  8.59
# 9    S190302057       SHAIKH ABDULKARIM SALIM  8.52
# 10   S190302054        SANDEEP MALHARI BORKAR  8.45
# 11   S190302020           GITE SARTHAK SANDIP  8.41
# 12   S190302024             HAKIM SANIYA MUSA  8.39
# 13   S190302039     MAHANGADE SHREYAS RAJARAM  8.39
# 14   S190302015       GANDHALE SWAPNIL SAMPAT  8.34
# 15   S190302031         KHACHANE DEVESH SUNIL  8.34
# 16   S190302017        GHARAT ISHWARI TUKARAM  8.30
# ...
